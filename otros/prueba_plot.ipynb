# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Nombre': ['Carlos', 'Lucia', 'Paula', 'Luis'],
    'Edad': [70, 65, 80, 75],
    'Sueldo': [18500, 24570, 32000, 15000]
}
df = pd.DataFrame(data, index=data['Nombre'])

plt.figure()
plt.title('Sueldos')
plt.xlabel('Nombre')
plt.ylabel('Euros anuales (€)')
df['Sueldo'].plot(kind='bar')
plt.show()

# %%
df
# Out:
#         Nombre  Edad  Sueldo
# Carlos  Carlos    70   18500
# Lucia    Lucia    65   24570
# Paula    Paula    80   32000
# Luis      Luis    75   15000
